# %%
data['spread'] = data['High'] - data['Low']
data['spread'].describe()
data['spread'].plot(figsize=(12,4), title='Daily High-Low Spread'); plt.show()

# %%
data['Volume'].plot(figsize=(12,4), title='Volume')
plt.yscale('log'); plt.show()

# %%
monthly = data['Close'].resample('M').last()
monthly.pct_change().plot(title='Monthly returns', figsize=(12,6))
plt.show()
